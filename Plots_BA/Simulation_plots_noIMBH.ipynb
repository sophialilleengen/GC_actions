# %%
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm
# %matplotlib inline

# %%
if 0: 
    x,y,z,vx,vy,vz=np.loadtxt('/home/milanov/Bachelorarbeit/x-y-z.dat', usecols=(30,31,32,33,34,35), unpack=True) 
elif 1:
    x_1,y_1,z_1,vx_1,vy_1,vz_1=np.loadtxt('/home/sophia/Dokumente/Bachelorarbeit-2/x-y-z_noIMBH1.dat', usecols=(29,30,31,32,33,34),unpack=True)
else:
    x,y,z,vx,vy,vz=np.loadtxt('C:\\Users\Sophia Milanov\Documents\Bachelorarbeit\BA Stand 13.11\Bachelorarbeit\\x-y-z.dat', usecols=(30,31,32,33,34,35), unpack=True)

# %%
if 0: 
    x,y,z,vx,vy,vz=np.loadtxt('/home/milanov/Bachelorarbeit/x-y-z.dat', usecols=(30,31,32,33,34,35), unpack=True) 
elif 1:
    x_2,y_2,z_2,vx_2,vy_2,vz_2=np.loadtxt('/home/sophia/Dokumente/Bachelorarbeit-2/x-y-z_noIMBH2.dat', usecols=(30,31,32,33,34,35),unpack=True)
else:
    x,y,z,vx,vy,vz=np.loadtxt('C:\\Users\Sophia Milanov\Documents\Bachelorarbeit\BA Stand 13.11\Bachelorarbeit\\x-y-z.dat', usecols=(30,31,32,33,34,35), unpack=True)

# %% [markdown]
# Ort Plots
# --

# %%
fig,axes=plt.subplots(nrows=2,ncols=3,figsize=(15,10))

ax00=axes[0,0]
ax01=axes[0,1]
ax02=axes[0,2]

ax10=axes[1,0]
ax11=axes[1,1]
ax12=axes[1,2]

H00, xedges00, yedges00, img00 = ax00.hist2d(x_1, y_1, bins=200, norm=LogNorm())
H01, xedges01, yedges01, img01 = ax01.hist2d(x_1, z_1, bins=200, norm=LogNorm())
H02, xedges02, yedges02, img02 = ax02.hist2d(y_1, z_1, bins=200, norm=LogNorm())

H10, xedges10, yedges10, img10 = ax10.hist2d(x_2, y_2, bins=200, norm=LogNorm())
H11, xedges11, yedges11, img11 = ax11.hist2d(x_2, z_2, bins=200, norm=LogNorm())
H12, xedges12, yedges12, img12 = ax12.hist2d(y_2, z_2, bins=200, norm=LogNorm())

ax00.set_aspect('equal')
ax01.set_aspect('equal')
ax02.set_aspect('equal')
ax10.set_aspect('equal')
ax11.set_aspect('equal')
ax12.set_aspect('equal')

ax00.set_xlim(-60,60)
ax01.set_xlim(-60,60)
ax02.set_xlim(-60,60)
ax00.set_ylim(-60,60)
ax01.set_ylim(-60,60)
ax02.set_ylim(-60,60)

ax10.set_xlim(-60,60)
ax11.set_xlim(-60,60)
ax12.set_xlim(-60,60)
ax10.set_ylim(-60,60)
ax11.set_ylim(-60,60)
ax12.set_ylim(-60,60)

ax01.set_title('noIMBH 1',fontsize=16,y=1.05)
ax11.set_title('noIMBH 2',fontsize=16,y=1.05)

ax00.set_xlabel('x [pc]',fontsize=14)
ax01.set_xlabel('x [pc]',fontsize=14)
ax02.set_xlabel('y [pc]',fontsize=14)

ax10.set_xlabel('x [pc]',fontsize=14)
ax11.set_xlabel('x [pc]',fontsize=14)
ax12.set_xlabel('y [pc]',fontsize=14)

labelx=-0.07
ax00.set_ylabel('y [pc]',fontsize=14)
ax01.set_ylabel('z [pc]',fontsize=14)
ax02.set_ylabel('z [pc]',fontsize=14)

ax10.set_ylabel('y [pc]',fontsize=14)
ax11.set_ylabel('z [pc]',fontsize=14)
ax12.set_ylabel('z [pc]',fontsize=14)

ax00.yaxis.set_label_coords(labelx, 0.5)
ax01.yaxis.set_label_coords(labelx, 0.5)
ax02.yaxis.set_label_coords(labelx, 0.5)

ax10.yaxis.set_label_coords(labelx, 0.5)
ax11.yaxis.set_label_coords(labelx, 0.5)
ax12.yaxis.set_label_coords(labelx, 0.5)

ax00.spines['top'].set_linewidth(1.5)
ax00.spines['right'].set_linewidth(1.5)
ax00.spines['bottom'].set_linewidth(1.5)
ax00.spines['left'].set_linewidth(1.5)

ax00.tick_params(length=8,width=1.5,labelsize=12)
ax00.tick_params(which='minor',length=4,width=1.5)

ax01.spines['top'].set_linewidth(1.5)
ax01.spines['right'].set_linewidth(1.5)
ax01.spines['bottom'].set_linewidth(1.5)
ax01.spines['left'].set_linewidth(1.5)

ax01.tick_params(length=8,width=1.5,labelsize=12)
ax01.tick_params(which='minor',length=4,width=1.5)

ax02.spines['top'].set_linewidth(1.5)
ax02.spines['right'].set_linewidth(1.5)
ax02.spines['bottom'].set_linewidth(1.5)
ax02.spines['left'].set_linewidth(1.5)

ax02.tick_params(length=8,width=1.5,labelsize=12)
ax02.tick_params(which='minor',length=4,width=1.5)

ax10.spines['top'].set_linewidth(1.5)
ax10.spines['right'].set_linewidth(1.5)
ax10.spines['bottom'].set_linewidth(1.5)
ax10.spines['left'].set_linewidth(1.5)

ax10.tick_params(length=8,width=1.5,labelsize=12)
ax10.tick_params(which='minor',length=4,width=1.5)

ax11.spines['top'].set_linewidth(1.5)
ax11.spines['right'].set_linewidth(1.5)
ax11.spines['bottom'].set_linewidth(1.5)
ax11.spines['left'].set_linewidth(1.5)

ax11.tick_params(length=8,width=1.5,labelsize=12)
ax11.tick_params(which='minor',length=4,width=1.5)

ax12.spines['top'].set_linewidth(1.5)
ax12.spines['right'].set_linewidth(1.5)
ax12.spines['bottom'].set_linewidth(1.5)
ax12.spines['left'].set_linewidth(1.5)

ax12.tick_params(length=8,width=1.5,labelsize=12)
ax12.tick_params(which='minor',length=4,width=1.5)


cbaxes0 = fig.add_axes([0.93, 0.5785, 0.01, 0.325]) 
cb0 = fig.colorbar(img00, cax = cbaxes0)
cb0.set_label('star counts',fontsize=14)
cbaxes1 = fig.add_axes([0.93, 0.124, 0.01, 0.325]) 
cb1 = fig.colorbar(img10, cax = cbaxes1)
cb1.set_label('star counts',fontsize=14)
fig.subplots_adjust(hspace=.4)
fig.savefig('../Bachelorarbeit-Entwurf/Plots/position_scatter_plot_noIMBH.pdf', format='pdf',bbox_inches='tight')

# %% [markdown]
# Velocity Plots
# ---

# %%
fig,axes=plt.subplots(nrows=2,ncols=3,figsize=(15,10))

ax00=axes[0,0]
ax01=axes[0,1]
ax02=axes[0,2]

ax10=axes[1,0]
ax11=axes[1,1]
ax12=axes[1,2]

H00, xedges00, yedges00, img00=ax00.hist2d(vx_1, vy_1, bins=200, norm=LogNorm())
H01, xedges01, yedges01, img01=ax01.hist2d(vx_1, vz_1, bins=200, norm=LogNorm())
H02, xedges02, yedges02, img02=ax02.hist2d(vy_1, vz_1, bins=200, norm=LogNorm())

H10, xedges10, yedges10, img10=ax10.hist2d(vx_2, vy_2, bins=200, norm=LogNorm())
H11, xedges11, yedges11, img11=ax11.hist2d(vx_2, vz_2, bins=200, norm=LogNorm())
H12, xedges12, yedges12, img12=ax12.hist2d(vy_2, vz_2, bins=200, norm=LogNorm())

ax00.set_aspect('equal')
ax01.set_aspect('equal')
ax02.set_aspect('equal')
ax10.set_aspect('equal')
ax11.set_aspect('equal')
ax12.set_aspect('equal')

ax00.set_xlim(-40,40)
ax01.set_xlim(-40,40)
ax02.set_xlim(-40,40)

ax00.set_ylim(-40,40)
ax01.set_ylim(-40,40)
ax02.set_ylim(-40,40)

ax10.set_xlim(-40,40)
ax11.set_xlim(-40,40)
ax12.set_xlim(-40,40)

ax10.set_ylim(-40,40)
ax11.set_ylim(-40,40)
ax12.set_ylim(-40,40)

ax01.set_title('noIMBH 1', fontsize=16,y=1.05)
ax11.set_title('noIMBH 2', fontsize=16,y=1.05)



ax00.set_xlabel('vx [km/s]', fontsize=14)
ax01.set_xlabel('vx [km/s]', fontsize=14)
ax02.set_xlabel('vy [km/s]', fontsize=14)

ax10.set_xlabel('vx [km/s]', fontsize=14)
ax11.set_xlabel('vx [km/s]', fontsize=14)
ax12.set_xlabel('vy [km/s]', fontsize=14)

labelx=-0.07
ax00.set_ylabel('vy [km/s]', fontsize=14)
ax01.set_ylabel('vz [km/s]', fontsize=14)
ax02.set_ylabel('vz [km/s]', fontsize=14)

ax10.set_ylabel('vy [km/s]', fontsize=14)
ax11.set_ylabel('vz [km/s]', fontsize=14)
ax12.set_ylabel('vz [km/s]', fontsize=14)

ax00.yaxis.set_label_coords(labelx, 0.5)
ax01.yaxis.set_label_coords(labelx, 0.5)
ax02.yaxis.set_label_coords(labelx, 0.5)

ax10.yaxis.set_label_coords(labelx, 0.5)
ax11.yaxis.set_label_coords(labelx, 0.5)
ax12.yaxis.set_label_coords(labelx, 0.5)

ax00.spines['top'].set_linewidth(1.5)
ax00.spines['right'].set_linewidth(1.5)
ax00.spines['bottom'].set_linewidth(1.5)
ax00.spines['left'].set_linewidth(1.5)

ax00.tick_params(length=8,width=1.5,labelsize=12)
ax00.tick_params(which='minor',length=4,width=1.5)

ax01.spines['top'].set_linewidth(1.5)
ax01.spines['right'].set_linewidth(1.5)
ax01.spines['bottom'].set_linewidth(1.5)
ax01.spines['left'].set_linewidth(1.5)

ax01.tick_params(length=8,width=1.5,labelsize=12)
ax01.tick_params(which='minor',length=4,width=1.5)

ax02.spines['top'].set_linewidth(1.5)
ax02.spines['right'].set_linewidth(1.5)
ax02.spines['bottom'].set_linewidth(1.5)
ax02.spines['left'].set_linewidth(1.5)

ax02.tick_params(length=8,width=1.5,labelsize=12)
ax02.tick_params(which='minor',length=4,width=1.5)
ax00.yaxis.set_label_coords(labelx, 0.5)
ax01.yaxis.set_label_coords(labelx, 0.5)
ax02.yaxis.set_label_coords(labelx, 0.5)

ax10.spines['top'].set_linewidth(1.5)
ax10.spines['right'].set_linewidth(1.5)
ax10.spines['bottom'].set_linewidth(1.5)
ax10.spines['left'].set_linewidth(1.5)

ax10.tick_params(length=8,width=1.5,labelsize=12)
ax10.tick_params(which='minor',length=4,width=1.5)

ax11.spines['top'].set_linewidth(1.5)
ax11.spines['right'].set_linewidth(1.5)
ax11.spines['bottom'].set_linewidth(1.5)
ax11.spines['left'].set_linewidth(1.5)

ax11.tick_params(length=8,width=1.5,labelsize=12)
ax11.tick_params(which='minor',length=4,width=1.5)

ax12.spines['top'].set_linewidth(1.5)
ax12.spines['right'].set_linewidth(1.5)
ax12.spines['bottom'].set_linewidth(1.5)
ax12.spines['left'].set_linewidth(1.5)

ax12.tick_params(length=8,width=1.5,labelsize=12)
ax12.tick_params(which='minor',length=4,width=1.5)


cbaxes0 = fig.add_axes([0.93, 0.5785, 0.01, 0.325]) 
cbaxes0.tick_params(length=4,width=1.5,labelsize=14)
cb0 = fig.colorbar(img00, cax = cbaxes0)  
cb0.set_label('star counts', fontsize=14)

cbaxes1 = fig.add_axes([0.93, 0.124, 0.01, 0.325]) 
cbaxes1.tick_params(length=4,width=1.5,labelsize=14)
cb1 = fig.colorbar(img10, cax = cbaxes1)  
cb1.set_label('star counts', fontsize=14)

fig.subplots_adjust(hspace=.4)

fig.savefig('../Bachelorarbeit-Entwurf/Plots/velocity_scatter_noIMBH.pdf',format='pdf',bbox_inches='tight')

# %% [markdown]
# 3D Ort Plot
# --

# %%
fig=plt.figure(figsize=(5,5))
ax=fig.add_subplot(111, projection='3d')
#ax.auto_scale_xyz([-100,100],[-100,100],[-100,100])
ax.w_xaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax.w_yaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax.w_zaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax.scatter(x,y,z,c='pink')
#ax.set_xlim3d(-100,100)
#ax.set_ylim3d(-100,100)
#ax.set_zlim3d(-100,100)
ax.set_xlabel('x [pc]')
ax.set_ylabel('y [pc]')
ax.set_zlabel('z [pc]')
ax.set_title('position of stars in globular cluster', y=1.05)

#plt.savefig('/home/sophia/Bachelorarbeit-Entwurf/Plots/xyz-plot.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-48a0ec2dd2dc> in <module>()
#       5 ax.w_yaxis.set_pane_color((1.0,1.0,1.0,1.0))
#       6 ax.w_zaxis.set_pane_color((1.0,1.0,1.0,1.0))
# ----> 7 ax.scatter(x,y,z,c='pink')
#       8 #ax.set_xlim3d(-100,100)
#       9 #ax.set_ylim3d(-100,100)
#
# NameError: name 'x' is not defined

# %% [markdown]
# 3D velocity plots
# --

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(vx,vy,vz)
ax.set_xlabel('vx[km/s]')
ax.set_ylabel('vy[km/s]')
ax.set_zlabel('vz[km/s]')
#plt.savefig('C:\\Users\Sophia Milanov\\Desktop\\Praesentation BA 18.11.15\Plots\\3D velocity plot')
