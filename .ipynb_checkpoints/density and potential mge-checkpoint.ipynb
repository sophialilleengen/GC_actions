# %%
import sys
sys.path.insert(0, '/home/sophia/Dokumente/Sophia_Uni/Bachelor/Bachelorarbeit/mge/')
sys.path.insert(0, '/home/sophia/Dokumente/Sophia_Uni/Bachelor/Bachelorarbeit/bachelor_thesis_ipython_notebooks/')

import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as cs
from astropy import units as un
from scipy.optimize import curve_fit
import scipy.integrate as intg

import mge_fit_1d
from Paolo_class import GCphasespace

# %matplotlib inline

# %%
r1, rho1 = np.loadtxt('densityfile_IMBH1.txt')

# %%
plt.loglog(r1, rho1, '.')

# %%
mge = mge_fit_1d.mge_fit_1d(r1, rho1, rbounds = (0.001, 10),  plot = 1)
# Out:
# Iteration:  1   chi2: 3.662  Nonzero: 9
# Iteration:  11   chi2: 2.011  Nonzero: 9
# Iteration:  15   chi2: 2.011  Nonzero: 9
# ############################################
#  Computation time: 0.14 seconds
#  Total Iterations:  15
# Nonzero Gaussians:  9
#  Unused Gaussians:  3
#  Chi2: 2.011
#  STDEV: 0.3007
#  MEANABSDEV: 0.112
# ############################################
#  Total_Counts      Sigma
# ############################################
#        159281     0.0114691
#         20255     0.0379211
#       9576.14     0.0908137
#       8014.24      0.211198
#       5842.92      0.520701
#       6310.76       1.05605
#        3317.7       2.10237
#       819.347       4.19387
#       85.5553       9.16323
# ############################################

# %% [markdown]
# to get mass multiply counts with $ 2 \pi \sigma^2$
#
# to get intrinsic counts divide by $\sqrt{2\pi \sigma ^2}$

# %%
counts, sigma = mge.sol

if 0:
    np.savetxt('MGE_results', mge.sol)

# %% [markdown]
# According to Cappellari 2008 (16) + (17); vereinfacht:
#
# $\Phi(R)= - \sqrt{2 / \pi} G \int_0^1{\sum_{j=1}^M{\frac{M_j \mathcal{H}_j(u)}{\sigma_j} \mathrm{d}u}}$
#
#
# $\mathcal{H}_j(u) =\mathrm{exp}\left(-\frac{u^2 R^2}{2 \sigma_j^2}\right) \qquad$

# %%
### SEE AND USE MGE_potential CLASS ### #TODO
# gravitational constant in pc^3/M_sol*s^2:
G = (un.m ** 3 / (un.kg * un.s ** 2)).to(un.pc ** 3 / (un.solMass * un.s ** 2), cs.G) 

def H_j(u, R, sigma):
    return np.exp(- u ** 2 * R ** 2 / (2. * sigma ** 2))

def integrand (u, R, sigma_arr, M_arr):
    H = np.zeros(len(R_arr))
    for i in range(len(R_arr)):
        H[i] = H_j(u, R, sigma_arr[i])
    return np.sum(M_arr * H / sigma_arr)

def Potential (R):
    a = - np.sqrt( 2. / cs.pi) * G    #[pc^3/M_sol*s^2]
    b = intg.quad(integrand, 0., 1., args = (sigma_arr = sigma, M_arr = counts))
