# %%
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm
# %matplotlib inline

# %%
if 0: 
    x,y,z,vx,vy,vz=np.loadtxt('/home/milanov/Bachelorarbeit/x-y-z.dat', usecols=(30,31,32,33,34,35), unpack=True) 
elif 1:
    x,y,z,vx,vy,vz=np.loadtxt('/home/sophia/Dokumente/Bachelorarbeit-2/x-y-z_IMBH1.dat', usecols=(30,31,32,33,34,35),unpack=True)
else:
    x,y,z,vx,vy,vz=np.loadtxt('C:\\Users\Sophia Milanov\Documents\Bachelorarbeit\BA Stand 13.11\Bachelorarbeit\\x-y-z.dat', usecols=(30,31,32,33,34,35), unpack=True)

# %% [markdown]
# Ort Plots
# --

# %%
plt.plot(x,y, '.')
plt.xlabel('x [pc]')
plt.ylabel('y [pc]')
plt.title('xy-plot')
plt.axes().set_aspect('equal')
#plt.savefig('xy-plot')

# %%
plt.scatter(x,y)
plt.xlim(-150,150)
plt.xlabel('x [pc]')
plt.ylabel('y [pc]')
plt.title('xy-plane')
plt.axes().set_aspect('equal')
#plt.savefig('C:\\Users\Sophia Milanov\\Desktop\\Praesentation BA 18.11.15\Plots\\xy-scatter')

# %%
fig,axes=plt.subplots(nrows=1,ncols=3,figsize=(15,5))

ax0=axes[0]
ax2=axes[1]
ax1=axes[2]

H0, xedges0, yedges0, img0 = ax0.hist2d(x, y, bins=200, norm=LogNorm())
H1, xedges1, yedges1, img0 = ax1.hist2d(y, z, bins=200, norm=LogNorm())
H2, xedges2, yedges2, img0 = ax2.hist2d(x, z, bins=200, norm=LogNorm())

ax0.set_aspect('equal')
ax1.set_aspect('equal')
ax2.set_aspect('equal')

ax0.set_xlim(-100,100)
ax1.set_xlim(-100,100)
ax2.set_xlim(-100,100)

ax0.set_ylim(-100,100)
ax1.set_ylim(-100,100)
ax2.set_ylim(-100,100)

#ax0.set_title('x y histogram')
#ax1.set_title('y z histogram')
#ax2.set_title('x z histogram')

ax0.set_xlabel('x [pc]',fontsize=14)
ax1.set_xlabel('y [pc]',fontsize=14)
ax2.set_xlabel('x [pc]',fontsize=14)

labelx=-0.08
ax0.set_ylabel('y [pc]',fontsize=14)
ax1.set_ylabel('z [pc]',fontsize=14)
ax2.set_ylabel('z [pc]',fontsize=14)

ax0.yaxis.set_label_coords(labelx, 0.5)
ax1.yaxis.set_label_coords(labelx, 0.5)
ax2.yaxis.set_label_coords(labelx, 0.5)

ax0.spines['top'].set_linewidth(1.5)
ax0.spines['right'].set_linewidth(1.5)
ax0.spines['bottom'].set_linewidth(1.5)
ax0.spines['left'].set_linewidth(1.5)

ax0.tick_params(length=8,width=1.5,labelsize=12)
ax0.tick_params(which='minor',length=4,width=1.5)

ax1.spines['top'].set_linewidth(1.5)
ax1.spines['right'].set_linewidth(1.5)
ax1.spines['bottom'].set_linewidth(1.5)
ax1.spines['left'].set_linewidth(1.5)

ax1.tick_params(length=8,width=1.5,labelsize=12)
ax1.tick_params(which='minor',length=4,width=1.5)

ax2.spines['top'].set_linewidth(1.5)
ax2.spines['right'].set_linewidth(1.5)
ax2.spines['bottom'].set_linewidth(1.5)
ax2.spines['left'].set_linewidth(1.5)

ax2.tick_params(length=8,width=1.5,labelsize=12)
ax2.tick_params(which='minor',length=4,width=1.5)
#fig.tight_layout()

#extent0= [yedges0[0], yedges0[-1], xedges0[0], xedges0[-1]]
#im0 = ax0.imshow(H0, cmap=plt.cm.jet, extent=extent0, norm=LogNorm())
#extent1= [yedges1[0], yedges1[-1], xedges1[0], xedges1[-1]]
#im1 = ax1.imshow(H1, cmap=plt.cm.jet, extent=extent1, norm=LogNorm())
#extent2= [yedges2[0], yedges2[-1], xedges2[0], xedges2[-1]]
#im2 = ax2.imshow(H2, cmap=plt.cm.jet, extent=extent2, norm=LogNorm())

cbaxes = fig.add_axes([0.93, 0.16, 0.01, 0.705]) 
cb = fig.colorbar(img0, cax = cbaxes)
#cbaxes.get_yaxis().labelpad = 20
cb.set_label('star counts',fontsize=14)
fig.savefig('../Bachelorarbeit-Entwurf/Plots/position_scatter_plot_IMBH1.pdf', format='pdf')

# %%
plt.hist2d(x, y, bins=200, norm=LogNorm())
plt.colorbar()
plt.axes().set_aspect('equal')
plt.xlabel('x [pc]')
plt.ylabel('y [pc]')
plt.title('star distribution')
#plt.savefig('C:\\Users\Sophia Milanov\\Desktop\\Praesentation BA 18.11.15\Plots\\2d histogram star distribution')
plt.show()

# %% [markdown]
# 3D Ort Plot
# --

# %%
fig=plt.figure(figsize=(5,5))
ax=fig.add_subplot(111, projection='3d')
#ax.auto_scale_xyz([-100,100],[-100,100],[-100,100])
ax.w_xaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax.w_yaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax.w_zaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax.scatter(x,y,z,c='pink')
#ax.set_xlim3d(-100,100)
#ax.set_ylim3d(-100,100)
#ax.set_zlim3d(-100,100)
ax.set_xlabel('x [pc]')
ax.set_ylabel('y [pc]')
ax.set_zlabel('z [pc]')
ax.set_title('position of stars in globular cluster', y=1.05)

#plt.savefig('/home/sophia/Bachelorarbeit-Entwurf/Plots/xyz-plot.pdf')

# %% [markdown]
# Velocity Plots
# ---

# %%
plt.scatter(vx,vy)
plt.xlabel('x-velocity[km/s]')
plt.ylabel('y-velocity[km/s]')
plt.title('xy-velocity-plot')
plt.axes().set_aspect('equal')
#plt.savefig('C:\\Users\Sophia Milanov\\Desktop\\Praesentation BA 18.11.15\Plots\\xy-velocity-plot_1')

# %%
plt.scatter(vy,vz)
plt.xlabel('y-velocity[km/s]')
plt.ylabel('z-velocity[km/s]')
plt.title('yz-velocity-plot')
plt.axes().set_aspect('equal')
#plt.savefig('C:\\Users\Sophia Milanov\\Desktop\\Praesentation BA 18.11.15\Plots\\yz-velocity-plot_1')

# %%
plt.scatter(vx,vz)
plt.xlabel('x-velocity[km/s]')
plt.ylabel('z-velocity[km/s]')
plt.title('xz-velocity-plot')
plt.axes().set_aspect('equal')
#plt.savefig('C:\\Users\Sophia Milanov\\Desktop\\Praesentation BA 18.11.15\Plots\\xz-velocity-plot_1')

# %%
fig,axes=plt.subplots(nrows=1,ncols=3,figsize=(15,5))

ax0=axes[0]
ax2=axes[1]
ax1=axes[2]

H0, xedges0, yedges0, img0=ax0.hist2d(vx, vy, bins=100, norm=LogNorm())
H1, xedges1, yedges1, img0=ax1.hist2d(vy, vz, bins=100, norm=LogNorm())
H2, xedges2, yedges2, img0=ax2.hist2d(vx, vz, bins=100, norm=LogNorm())

ax0.set_aspect('equal')
ax1.set_aspect('equal')
ax2.set_aspect('equal')

ax0.set_xlim(-120,120)
ax1.set_xlim(-120,120)
ax2.set_xlim(-120,120)

ax0.set_ylim(-100,100)
ax1.set_ylim(-100,100)
ax2.set_ylim(-100,100)

#ax0.set_title('vx vy histogram')
#ax1.set_title('vy vz histogram')
#ax2.set_title('vx vz histogram')

ax0.set_xlabel('vx [km/s]', fontsize=14)
ax1.set_xlabel('vy [km/s]', fontsize=14)
ax2.set_xlabel('vx [km/s]', fontsize=14)

labelx=-0.08
ax0.set_ylabel('vy [km/s]', fontsize=14)
ax1.set_ylabel('vz [km/s]', fontsize=14)
ax2.set_ylabel('vz [km/s]', fontsize=14)

ax0.yaxis.set_label_coords(labelx, 0.5)
ax1.yaxis.set_label_coords(labelx, 0.5)
ax2.yaxis.set_label_coords(labelx, 0.5)
ax0.spines['top'].set_linewidth(1.5)
ax0.spines['right'].set_linewidth(1.5)
ax0.spines['bottom'].set_linewidth(1.5)
ax0.spines['left'].set_linewidth(1.5)

ax0.tick_params(length=8,width=1.5,labelsize=12)
ax0.tick_params(which='minor',length=4,width=1.5)

ax1.spines['top'].set_linewidth(1.5)
ax1.spines['right'].set_linewidth(1.5)
ax1.spines['bottom'].set_linewidth(1.5)
ax1.spines['left'].set_linewidth(1.5)

ax1.tick_params(length=8,width=1.5,labelsize=12)
ax1.tick_params(which='minor',length=4,width=1.5)

ax2.spines['top'].set_linewidth(1.5)
ax2.spines['right'].set_linewidth(1.5)
ax2.spines['bottom'].set_linewidth(1.5)
ax2.spines['left'].set_linewidth(1.5)

ax2.tick_params(length=8,width=1.5,labelsize=12)
ax2.tick_params(which='minor',length=4,width=1.5)

#extent0= [yedges0[0], yedges0[-1], xedges0[0], xedges0[-1]]
#im0 = ax.imshow(H0, cmap=plt.cm.jet, extent=extent0, norm=LogNorm())
#extent1= [yedges1[0], yedges1[-1], xedges1[0], xedges1[-1]]
#im1 = ax.imshow(H1, cmap=plt.cm.jet, extent=extent1, norm=LogNorm())
#extent2= [yedges2[0], yedges2[-1], xedges2[0], xedges2[-1]]
#im2 = ax.imshow(H2, cmap=plt.cm.jet, extent=extent2, norm=LogNorm())

cbaxes = fig.add_axes([0.93, 0.16, 0.01, 0.705]) 
cbaxes.tick_params(length=4,width=1.5,labelsize=14)
cb = fig.colorbar(img0, cax = cbaxes)  
cb.set_label('star counts', fontsize=14)
#fig.savefig('../Bachelorarbeit-Entwurf/Plots/velocity_scatter_IMBH1.pdf',format='pdf')

# %% [markdown]
# 3D velocity plots
# --

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(vx,vy,vz)
ax.set_xlabel('vx[km/s]')
ax.set_ylabel('vy[km/s]')
ax.set_zlabel('vz[km/s]')
#plt.savefig('C:\\Users\Sophia Milanov\\Desktop\\Praesentation BA 18.11.15\Plots\\3D velocity plot')
